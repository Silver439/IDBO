# %%
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
import torch
import botorch
from pak.choose import *
from pak.function import *
from pak.GPmodel import fit_gp_model
from pak.plotfunc import visualize_2d_contour
from skopt.sampler import Lhs
import warnings
warnings.filterwarnings("ignore")
torch.set_default_tensor_type(torch.DoubleTensor)

func = 'Fn7'
noise = 'M'
funcname = func + noise

# %%
fn = choose(funcname)[0]
f = choose(funcname)[1]
search_space = [[-5.0, 5.0], [-5.0, 5.0]] 
bounds = torch.tensor([[-5.0, -5.0], [5.0, 5.0]])
budgets = 300

# %%
lhs = Lhs()
samples = lhs.generate(search_space, n_samples=round(0.1*budgets))
train_x = torch.tensor(samples)
train_y = []
for x in train_x:
    train_y.append(fn(x.numpy()))
train_y = torch.tensor(train_y)

# %%
for i in tqdm(range(budgets-len(samples))):

    model, likelihood = fit_gp_model(train_x, train_y)

    policy = botorch.acquisition.logei.qLogNoisyExpectedImprovement(
        model, train_x, maximize = False
    )

    next_x, acq_val = botorch.optim.optimize_acqf( 
        policy,
        bounds=bounds,
        q=1,
        num_restarts=40,
        raw_samples=100,
    )

    next_x_obs = train_x[train_y.argmin()].reshape(1, 2)

    next_y = torch.tensor(fn(next_x.numpy()))

    train_x = torch.cat([train_x, next_x])
    train_y = torch.cat([train_y, next_y])
# Out:
#   0%|          | 0/270 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 5
#       1 for i in tqdm(range(budgets-len(samples))):
#       3     model, likelihood = fit_gp_model(train_x, train_y)
# ----> 5     policy = botorch.acquisition.logei.qLogNoisyExpectedImprovement(
#       6         model, train_x, maximize = False
#       7     )
#       9     next_x, acq_val = botorch.optim.optimize_acqf(
#      10         policy,
#      11         bounds=bounds,
#    (...)
#      14         raw_samples=100,
#      15     )
#      17     next_x_obs = train_x[train_y.argmin()].reshape(1, 2)
#
# AttributeError: module 'botorch.acquisition' has no attribute 'logei'

# %%
x1_range = torch.linspace(-5, 5, 1000)
x2_range = torch.linspace(-5, 5, 1000)
X1, X2 = torch.meshgrid(x1_range, x2_range, indexing="ij")
xs = torch.vstack((X1.flatten(), X2.flatten())).transpose(-1, -2)

# %%
data = f(xs.numpy())
visualize_2d_contour(name='Objective function '+funcname+'(noisefree)',x1_range=x1_range,x2_range=x2_range, data=data, train_x=train_x,labelx="EI")
